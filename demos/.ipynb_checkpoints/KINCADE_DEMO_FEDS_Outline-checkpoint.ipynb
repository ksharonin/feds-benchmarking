# %% [markdown]
# # Demo: FEDS Archived Perimeters V.S. NIFC Historic Perimeters for Kincade Fire 2019

# %% [markdown]
# ### Summary
#
# This notebook demonstrates an Object Oriented Programming (OOP) implementation of a benchmarking system to compare a FEDS fire perimeter against other fire perimeter data sources, and then store in an output object. This notebook focuses on the 2019 Kincade Fire located in CA
#
# #### Sources for demonstration:
# - <span style='color:red'> **FEDS Archived Perimeters** </span>, labeled as `"public.eis_fire_lf_perimeter_archive"` and graphically displayed as <span style='color:red'> red </span>
# -  <span style='color:#B8860B'> **NIFC InterAgency History Perimeters** </span>, labeled as `"Downloaded_InterAgencyFirePerimeterHistory_All_Years_View"`and graphically displayed as  <span style='color:#B8860B'> transparent gold with hatch style </span>
#
# The FEDS input and reference input can use either a pre-defined setting or can accept (valid) user-written paths to shape files.
# - For Input all settings, please see **section INPUT SETTINGS of README.md**
# - Output settings can also be modified to control if calculations are printed, plotted, and/or stored into a file (with location and file type of choice); for more detail on outputs please see **section OUTPUT SETTINGS of README.md**
#
# #### Motivation
# FEDS-PEC eliminates the need for users to recreate/repeat solutions when conducting geospatial data evaluations. By leveraging this module, researchers and analysts can quickly and efficiently compare the FEDS fireperimeter dataset against a reference data set of their choosing. Users can focus their efforts on dataset selection and analysis, rather than spending time implementing and testing software for comparisons and calculations.
#
# #### Debugging
# Should users encounter abnormal errors, users are encouraged to restart the kernel of the notebook and re-run blocks.

# %% [markdown]
# ### User Inputs for Comparison: time, bbox, FEDS set, reference set
#
# Note for inputs:
#
# FEDS Input: you must specify a valid title (e.g. firenrt) and collection (e.g. public.eis_fire_lf_perimeter_archive) according to documentation. Please see **section INPUT SETTINGS of README.md** for valid titles and corresponding collections
#
# Reference Input: See **section INPUT SETTINGS of README.md** for valid titles and corresponding collections

# %%
import sys
sys.path.append('../') # local path append

import Utilities
import Input_FEDS
import Input_Reference
import Output_Calculation

from Input_FEDS import InputFEDS
from Input_Reference import InputReference
from Output_Calculation import OutputCalculation
from Utilities import *

# %%
# this is the ONLY section users are intended to modify!
# inputs for searching FEDS and nifc sets

# START TIME
year_start = 2019
month_start = 10
day_start = 23
hour_start = 0
minute_start = 0
second_start = 0
tz_offset_hours_start = 0
tz_offset_minutes_start = 0
utc_offset_start = '00:00'

# END TIME
year_stop = 2019
month_stop = 11
day_stop = 14
hour_stop = 0
minute_stop = 0
second_stop = 0
tz_offset_hours_stop = 0
tz_offset_minutes_stop = 0
utc_offset_stop = '00:00'

# CRS - 4326 RECOMMENDED FEDS FIRE PERIM DEFAULT
crs = 3857

# BBOX FOR SEARCH - [lon, lat, lon, lat]
search_bbox = ["-125.0", "24.396308", "-66.93457", "49.384358"] 

# DAY SEARCH RANGE- acceptable distance warning to search from feds -> reference (e.g. if reference polygon is 8 days away, output a warning)
# note by default, any results not of the same year are eliminated
day_search_range = 7 

# FEDS INPUT SETTINGS
feds_title = "firenrt"
feds_collection =  "public.eis_fire_lf_perimeter_archive"
feds_access_type = "api"
feds_limit = 9000 # amount of features to consider for FEDS API access; warning appears if it misses any entries
feds_filter = False
feds_apply_finalfire = True

# REFERENCE INPUT SETTINGS 
ref_title = "Downloaded_InterAgencyFirePerimeterHistory_All_Years_View"
ref_control_type = "defined" # or "custom"
ref_custom_url = "none"
ref_custom_read_type = "none"
ref_filter = False # False or a valid query

# OUTPUT SETTINGS - User discretion advised for path functionality
print_on = True
plot_on = True
name_for_output_file = "kincade_fire_demo"
output_format = "csv"
user_path = "/projects/my-public-bucket/VEDA-PEC/results"
output_maap_url = f"{user_path}/{name_for_output_file}.{output_format}"

# %% [markdown]
# ### Argument Processing: format and check to report any issues
# - Note: upon instance instantiation we can also get reports back of invalidity -> any warnings/errors should be addressed

# %%
# start date formatting
search_start = Utilities.format_datetime(year_start, 
                                         month_start, 
                                         day_start, 
                                         hour_start, 
                                         minute_start, 
                                         second_start, 
                                         tz_offset_hours_start, 
                                         tz_offset_minutes_start,
                                         utc_offset_start)
# stop date formatting
search_stop = Utilities.format_datetime(year_stop, 
                                        month_stop, 
                                        day_stop, 
                                        hour_stop, 
                                        minute_stop, 
                                        second_stop, 
                                        tz_offset_hours_stop, 
                                        tz_offset_minutes_stop,
                                        utc_offset_stop)

# bound check the bbox
assert Utilities.check_bbox(search_bbox), f"ERR: passed bbox {search_bbox} is not valid; check bounds"
assert  Utilities.check_crs(crs), f"ERR: invalid crs provided {crs}; please enter valid ESPG CRS number"

# %% [markdown]
# ### Using Inputs: Instantiate Inputs + Calculation Output
#
# With our inputs, we are ready to start; run this to get the program to fetch the FEDS candidates in the provided time/location window, along with an intersecting NIFC in the specific day range

# %%
# create instances to track properties
print('You may see an ERROR 1 occur; ignore this unless block throws actual exception...')

feds_firenrt = InputFEDS(
                 feds_title, 
                 feds_collection, 
                 search_start,
                 search_stop,
                 search_bbox,
                 crs,
                 feds_access_type,
                 feds_limit,
                 feds_filter,
                 feds_apply_finalfire
                )

nifc_search = InputReference( 
                 search_start,
                 search_stop,
                 search_bbox,
                 crs,
                 ref_title,
                 ref_control_type,
                 ref_custom_url,
                 ref_custom_read_type,
                 ref_filter,
                )

my_output = OutputCalculation(
                feds_firenrt,
                nifc_search,
                output_format, 
                output_maap_url,
                day_search_range,
                print_on,
                plot_on
                )
# Out:
# You may see an ERROR 1 occur; ignore this unless block throws actual exception...
# Running FEDS-Reference Match Algorithm:  13%|█▎        | 17/131 [00:08<00:59,  1.92polygon/s]
# TIME MATCH WARNING: the intersecting pair does not have a timestamp difference within the specified day search range window: 7
# Intersection pair will still be included for user inspection; FEDS at index 17 and Reference at index [448].
# Running FEDS-Reference Match Algorithm:  76%|███████▌  | 99/131 [00:52<00:17,  1.86polygon/s]
# TIME MATCH WARNING: the intersecting pair does not have a timestamp difference within the specified day search range window: 7
# Intersection pair will still be included for user inspection; FEDS at index 99 and Reference at index [301].
# Running FEDS-Reference Match Algorithm:  77%|███████▋  | 101/131 [00:53<00:16,  1.87polygon/s]
# TIME MATCH WARNING: the intersecting pair does not have a timestamp difference within the specified day search range window: 7
# Intersection pair will still be included for user inspection; FEDS at index 101 and Reference at index [299].
# Running FEDS-Reference Match Algorithm:  85%|████████▌ | 112/131 [00:59<00:10,  1.90polygon/s]
# TIME MATCH WARNING: the intersecting pair does not have a timestamp difference within the specified day search range window: 7
# Intersection pair will still be included for user inspection; FEDS at index 112 and Reference at index [396].
# Running FEDS-Reference Match Algorithm:  91%|█████████ | 119/131 [01:02<00:06,  1.88polygon/s]
# TIME MATCH WARNING: the intersecting pair does not have a timestamp difference within the specified day search range window: 7
# Intersection pair will still be included for user inspection; FEDS at index 119 and Reference at index [453, 462, 468, 475].
# Running FEDS-Reference Match Algorithm: 100%|██████████| 131/131 [01:09<00:00,  1.89polygon/s]
# DATE MATCHING COMPLETE
# CALCULATED A RESULT: POLYGON FEDS AT INDEX 3785 AGAINST REFERENCE POLYGON AT INDEX 4851:
# Ratio: 1.2169222233234451, Accuracy: 1.512384916039911, Precision: 0.7115263140399016, Recall: 0.8658721840345728, IOU: 0.3990733289795567, F1 0.7811480032317251, Symmetric Ratio: 0.4851778552542943
# All measurements in units metre
# NO CALCULATION RESULTS, SKIP FEDS INDEX 316 & REFERENCE INDEX 316
# NO CALCULATION RESULTS, SKIP FEDS INDEX 473 & REFERENCE INDEX 473
# NO CALCULATION RESULTS, SKIP FEDS INDEX 1276 & REFERENCE INDEX 1276
# NO CALCULATION RESULTS, SKIP FEDS INDEX 187 & REFERENCE INDEX 187
# NO CALCULATION RESULTS, SKIP FEDS INDEX 378 & REFERENCE INDEX 378
# NO CALCULATION RESULTS, SKIP FEDS INDEX 1241 & REFERENCE INDEX 1241
# NO CALCULATION RESULTS, SKIP FEDS INDEX 1600 & REFERENCE INDEX 1600
# NO CALCULATION RESULTS, SKIP FEDS INDEX 2769 & REFERENCE INDEX 2769
# NO CALCULATION RESULTS, SKIP FEDS INDEX 2494 & REFERENCE INDEX 2494
# NO CALCULATION RESULTS, SKIP FEDS INDEX 967 & REFERENCE INDEX 967
# NO CALCULATION RESULTS, SKIP FEDS INDEX 1749 & REFERENCE INDEX 1749
# NO CALCULATION RESULTS, SKIP FEDS INDEX 1420 & REFERENCE INDEX 1420
# NO CALCULATION RESULTS, SKIP FEDS INDEX 1171 & REFERENCE INDEX 1171
# NO CALCULATION RESULTS, SKIP FEDS INDEX 1183 & REFERENCE INDEX 1183
# NO CALCULATION RESULTS, SKIP FEDS INDEX 3289 & REFERENCE INDEX 3289
# NO CALCULATION RESULTS, SKIP FEDS INDEX 1778 & REFERENCE INDEX 1778
# CALCULATED A RESULT: POLYGON FEDS AT INDEX 3095 AGAINST REFERENCE POLYGON AT INDEX 11426:
# Ratio: 1.6005785868266038, Accuracy: 0.610760875226477, Precision: 0.6241583598527608, Recall: 0.9990145055691426, IOU: 0.4794275641404847, F1 0.7683017238007837, Symmetric Ratio: 0.6025495756883285
# All measurements in units metre
# NO CALCULATION RESULTS, SKIP FEDS INDEX 1365 & REFERENCE INDEX 1365
# NO CALCULATION RESULTS, SKIP FEDS INDEX 961 & REFERENCE INDEX 961
# NO CALCULATION RESULTS, SKIP FEDS INDEX 3183 & REFERENCE INDEX 3183
# NO CALCULATION RESULTS, SKIP FEDS INDEX 1111 & REFERENCE INDEX 1111
# NO CALCULATION RESULTS, SKIP FEDS INDEX 2888 & REFERENCE INDEX 2888
# NO CALCULATION RESULTS, SKIP FEDS INDEX 2827 & REFERENCE INDEX 2827
# NO CALCULATION RESULTS, SKIP FEDS INDEX 1743 & REFERENCE INDEX 1743
# NO CALCULATION RESULTS, SKIP FEDS INDEX 2400 & REFERENCE INDEX 2400
# NO CALCULATION RESULTS, SKIP FEDS INDEX 1020 & REFERENCE INDEX 1020
# NO CALCULATION RESULTS, SKIP FEDS INDEX 3237 & REFERENCE INDEX 3237
# NO CALCULATION RESULTS, SKIP FEDS INDEX 2262 & REFERENCE INDEX 2262
# NO CALCULATION RESULTS, SKIP FEDS INDEX 2304 & REFERENCE INDEX 2304
# NO CALCULATION RESULTS, SKIP FEDS INDEX 2279 & REFERENCE INDEX 2279
# NO CALCULATION RESULTS, SKIP FEDS INDEX 2048 & REFERENCE INDEX 2048
# NO CALCULATION RESULTS, SKIP FEDS INDEX 2214 & REFERENCE INDEX 2214
# NO CALCULATION RESULTS, SKIP FEDS INDEX 1692 & REFERENCE INDEX 1692
# NO CALCULATION RESULTS, SKIP FEDS INDEX 825 & REFERENCE INDEX 825
# NO CALCULATION RESULTS, SKIP FEDS INDEX 3039 & REFERENCE INDEX 3039
# NO CALCULATION RESULTS, SKIP FEDS INDEX 3139 & REFERENCE INDEX 3139
# NO CALCULATION RESULTS, SKIP FEDS INDEX 1213 & REFERENCE INDEX 1213
# NO CALCULATION RESULTS, SKIP FEDS INDEX 745 & REFERENCE INDEX 745
# NO CALCULATION RESULTS, SKIP FEDS INDEX 1006 & REFERENCE INDEX 1006
# NO CALCULATION RESULTS, SKIP FEDS INDEX 1141 & REFERENCE INDEX 1141
# NO CALCULATION RESULTS, SKIP FEDS INDEX 230 & REFERENCE INDEX 230
# NO CALCULATION RESULTS, SKIP FEDS INDEX 360 & REFERENCE INDEX 360
# NO CALCULATION RESULTS, SKIP FEDS INDEX 1536 & REFERENCE INDEX 1536
# NO CALCULATION RESULTS, SKIP FEDS INDEX 1062 & REFERENCE INDEX 1062
# NO CALCULATION RESULTS, SKIP FEDS INDEX 3399 & REFERENCE INDEX 3399
# NO CALCULATION RESULTS, SKIP FEDS INDEX 1672 & REFERENCE INDEX 1672
# NO CALCULATION RESULTS, SKIP FEDS INDEX 2800 & REFERENCE INDEX 2800
# NO CALCULATION RESULTS, SKIP FEDS INDEX 1464 & REFERENCE INDEX 1464
# NO CALCULATION RESULTS, SKIP FEDS INDEX 2567 & REFERENCE INDEX 2567
# NO CALCULATION RESULTS, SKIP FEDS INDEX 644 & REFERENCE INDEX 644
# NO CALCULATION RESULTS, SKIP FEDS INDEX 2244 & REFERENCE INDEX 2244
# NO CALCULATION RESULTS, SKIP FEDS INDEX 688 & REFERENCE INDEX 688
# NO CALCULATION RESULTS, SKIP FEDS INDEX 789 & REFERENCE INDEX 789
# NO CALCULATION RESULTS, SKIP FEDS INDEX 3364 & REFERENCE INDEX 3364
# NO CALCULATION RESULTS, SKIP FEDS INDEX 2598 & REFERENCE INDEX 2598
# NO CALCULATION RESULTS, SKIP FEDS INDEX 32 & REFERENCE INDEX 32
# NO CALCULATION RESULTS, SKIP FEDS INDEX 946 & REFERENCE INDEX 946
# NO CALCULATION RESULTS, SKIP FEDS INDEX 2932 & REFERENCE INDEX 2932
# NO CALCULATION RESULTS, SKIP FEDS INDEX 2444 & REFERENCE INDEX 2444
# NO CALCULATION RESULTS, SKIP FEDS INDEX 272 & REFERENCE INDEX 272
# NO CALCULATION RESULTS, SKIP FEDS INDEX 908 & REFERENCE INDEX 908
# NO CALCULATION RESULTS, SKIP FEDS INDEX 3333 & REFERENCE INDEX 3333
# NO CALCULATION RESULTS, SKIP FEDS INDEX 1644 & REFERENCE INDEX 1644
# NO CALCULATION RESULTS, SKIP FEDS INDEX 561 & REFERENCE INDEX 561
# NO CALCULATION RESULTS, SKIP FEDS INDEX 2023 & REFERENCE INDEX 2023
# NO CALCULATION RESULTS, SKIP FEDS INDEX 2170 & REFERENCE INDEX 2170
# NO CALCULATION RESULTS, SKIP FEDS INDEX 2123 & REFERENCE INDEX 2123
# NO CALCULATION RESULTS, SKIP FEDS INDEX 2389 & REFERENCE INDEX 2389
# NO CALCULATION RESULTS, SKIP FEDS INDEX 3566 & REFERENCE INDEX 3566
# NO CALCULATION RESULTS, SKIP FEDS INDEX 1508 & REFERENCE INDEX 1508
# NO CALCULATION RESULTS, SKIP FEDS INDEX 2537 & REFERENCE INDEX 2537
# NO CALCULATION RESULTS, SKIP FEDS INDEX 1903 & REFERENCE INDEX 1903
# NO CALCULATION RESULTS, SKIP FEDS INDEX 2640 & REFERENCE INDEX 2640
# NO CALCULATION RESULTS, SKIP FEDS INDEX 1946 & REFERENCE INDEX 1946
# NO CALCULATION RESULTS, SKIP FEDS INDEX 2345 & REFERENCE INDEX 2345
# NO CALCULATION RESULTS, SKIP FEDS INDEX 2870 & REFERENCE INDEX 2870
# NO CALCULATION RESULTS, SKIP FEDS INDEX 2723 & REFERENCE INDEX 2723
# NO CALCULATION RESULTS, SKIP FEDS INDEX 1820 & REFERENCE INDEX 1820
# CALCULATED A RESULT: POLYGON FEDS AT INDEX 2995 AGAINST REFERENCE POLYGON AT INDEX 11287:
# Ratio: 1.0768937433017958, Accuracy: 1.5525343121533373, Precision: 0.8841178733805377, Recall: 0.9521010061847904, IOU: 0.6480590560229462, F1 0.9168509551876862, Symmetric Ratio: 0.1726917309322174
# All measurements in units metre
# NO CALCULATION RESULTS, SKIP FEDS INDEX 3479 & REFERENCE INDEX 3479
# NO CALCULATION RESULTS, SKIP FEDS INDEX 3521 & REFERENCE INDEX 3521
# NO CALCULATION RESULTS, SKIP FEDS INDEX 3562 & REFERENCE INDEX 3562
# NO CALCULATION RESULTS, SKIP FEDS INDEX 2485 & REFERENCE INDEX 2485
# NO CALCULATION RESULTS, SKIP FEDS INDEX 2681 & REFERENCE INDEX 2681
# NO CALCULATION RESULTS, SKIP FEDS INDEX 2128 & REFERENCE INDEX 2128
# NO CALCULATION RESULTS, SKIP FEDS INDEX 3836 & REFERENCE INDEX 3836
# NO CALCULATION RESULTS, SKIP FEDS INDEX 3643 & REFERENCE INDEX 3643
# NO CALCULATION RESULTS, SKIP FEDS INDEX 3563 & REFERENCE INDEX 3563
# NO CALCULATION RESULTS, SKIP FEDS INDEX 600 & REFERENCE INDEX 600
# NO CALCULATION RESULTS, SKIP FEDS INDEX 3655 & REFERENCE INDEX 3655
# NO CALCULATION RESULTS, SKIP FEDS INDEX 864 & REFERENCE INDEX 864
# NO CALCULATION RESULTS, SKIP FEDS INDEX 1575 & REFERENCE INDEX 1575
# NO CALCULATION RESULTS, SKIP FEDS INDEX 1859 & REFERENCE INDEX 1859
# NO CALCULATION RESULTS, SKIP FEDS INDEX 2764 & REFERENCE INDEX 2764
# NO CALCULATION RESULTS, SKIP FEDS INDEX 3437 & REFERENCE INDEX 3437
# NO CALCULATION RESULTS, SKIP FEDS INDEX 3603 & REFERENCE INDEX 3603
# NO CALCULATION RESULTS, SKIP FEDS INDEX 1311 & REFERENCE INDEX 1311
# NO CALCULATION RESULTS, SKIP FEDS INDEX 3074 & REFERENCE INDEX 3074
# CALCULATED A RESULT: POLYGON FEDS AT INDEX 3745 AGAINST REFERENCE POLYGON AT INDEX 4855:
# Ratio: 2.7713492411867087, Accuracy: 0.45685029550792355, Precision: 0.3160743892650968, Recall: 0.8759525188483783, IOU: 0.24208483040747772, F1 0.4645300463198404, Symmetric Ratio: 2.0194442034899627
# All measurements in units metre
# NO CALCULATION RESULTS, SKIP FEDS INDEX 1979 & REFERENCE INDEX 1979
# CALCULATED A RESULT: POLYGON FEDS AT INDEX 3796 AGAINST REFERENCE POLYGON AT INDEX 4851:
# Ratio: 0.0061934596759765275, Accuracy: 0.6579620239939673, Precision: 0.9999999999999996, Recall: 0.006193459675976525, IOU: 0.005891713551489381, F1 0.012310673690864575, Symmetric Ratio: 0.993806540324024
# All measurements in units metre
# NO CALCULATION RESULTS, SKIP FEDS INDEX 717 & REFERENCE INDEX 717
# NO CALCULATION RESULTS, SKIP FEDS INDEX 3891 & REFERENCE INDEX 3891
# NO CALCULATION RESULTS, SKIP FEDS INDEX 1721 & REFERENCE INDEX 1721
# CALCULATED A RESULT: POLYGON FEDS AT INDEX 3711 AGAINST REFERENCE POLYGON AT INDEX 11389:
# Ratio: 3.520491171841603, Accuracy: 0.9692269392732942, Precision: 0.2753324935752905, Recall: 0.9693056129529452, IOU: 0.1878208374765904, F1 0.4288496873927351, Symmetric Ratio: 2.5818799459356274
# All measurements in units metre
# NO CALCULATION RESULTS, SKIP FEDS INDEX 99 & REFERENCE INDEX 99
# CALCULATED A RESULT: POLYGON FEDS AT INDEX 3683 AGAINST REFERENCE POLYGON AT INDEX 11311:
# Ratio: 4.078200613358667, Accuracy: 0.4116809793110243, Precision: 0.2452061815508466, Recall: 0.9999999999999992, IOU: 0.2147279247511934, F1 0.39384028955823785, Symmetric Ratio: 3.0782006133586686
# All measurements in units metre
# NO CALCULATION RESULTS, SKIP FEDS INDEX 3862 & REFERENCE INDEX 3862
# NO CALCULATION RESULTS, SKIP FEDS INDEX 1354 & REFERENCE INDEX 1354
# NO CALCULATION RESULTS, SKIP FEDS INDEX 3258 & REFERENCE INDEX 3258
# NO CALCULATION RESULTS, SKIP FEDS INDEX 1083 & REFERENCE INDEX 1083
# CALCULATED A RESULT: POLYGON FEDS AT INDEX 2953 AGAINST REFERENCE POLYGON AT INDEX 11374:
# Ratio: 0.9908844458530985, Accuracy: 0.61440182906946, Precision: 0.7657478067044744, Recall: 0.7587675911095888, IOU: 0.49499084309794555, F1 0.762241718940604, Symmetric Ratio: 0.4733492636338995
# All measurements in units metre
# NO CALCULATION RESULTS, SKIP FEDS INDEX 1596 & REFERENCE INDEX 1596
# NO CALCULATION RESULTS, SKIP FEDS INDEX 3275 & REFERENCE INDEX 3275
# NO CALCULATION RESULTS, SKIP FEDS INDEX 1329 & REFERENCE INDEX 1329
# NO CALCULATION RESULTS, SKIP FEDS INDEX 1320 & REFERENCE INDEX 1320
# NO CALCULATION RESULTS, SKIP FEDS INDEX 949 & REFERENCE INDEX 949
# NO CALCULATION RESULTS, SKIP FEDS INDEX 964 & REFERENCE INDEX 964
# CALCULATED A RESULT: POLYGON FEDS AT INDEX 3075 AGAINST REFERENCE POLYGON AT INDEX 11434:
# Ratio: 503.13249542849087, Accuracy: 0.4372870784083376, Precision: 0.001987548029765705, Recall: 0.9999999999999998, IOU: 0.001984763349907215, F1 0.003967211037051054, Symmetric Ratio: 502.13249542849115
# All measurements in units metre
# CALCULATED A RESULT: POLYGON FEDS AT INDEX 3075 AGAINST REFERENCE POLYGON AT INDEX 11443:
# Ratio: 2768.482193413801, Accuracy: 0.4370748440679838, Precision: 0.00036120875271619695, Recall: 1.0, IOU: 0.00036114644030718005, F1 0.0007221566561273684, Symmetric Ratio: 2767.482193413802
# All measurements in units metre
# CALCULATED A RESULT: POLYGON FEDS AT INDEX 3075 AGAINST REFERENCE POLYGON AT INDEX 11449:
# Ratio: 46.99625797996787, Accuracy: 0.4423176364723813, Precision: 0.021278289867807127, Recall: 1.0000000000000002, IOU: 0.02116220534523594, F1 0.04166991520119625, Symmetric Ratio: 45.99625797996789
# All measurements in units metre
# CALCULATED A RESULT: POLYGON FEDS AT INDEX 3075 AGAINST REFERENCE POLYGON AT INDEX 11456:
# Ratio: 58.57176360300781, Accuracy: 0.4414088794550468, Precision: 0.01639155341270367, Recall: 0.9600821915749553, IOU: 0.0163568602356463, F1 0.0322327939784707, Symmetric Ratio: 57.65159921985671
# All measurements in units metre
# NO CALCULATION RESULTS, SKIP FEDS INDEX 3184 & REFERENCE INDEX 3184
# NO CALCULATION RESULTS, SKIP FEDS INDEX 2725 & REFERENCE INDEX 2725
# NO CALCULATION RESULTS, SKIP FEDS INDEX 2724 & REFERENCE INDEX 2724
# NO CALCULATION RESULTS, SKIP FEDS INDEX 466 & REFERENCE INDEX 466
# NO CALCULATION RESULTS, SKIP FEDS INDEX 143 & REFERENCE INDEX 143
# NO CALCULATION RESULTS, SKIP FEDS INDEX 517 & REFERENCE INDEX 517
# NO CALCULATION RESULTS, SKIP FEDS INDEX 422 & REFERENCE INDEX 422
# NO CALCULATION RESULTS, SKIP FEDS INDEX 1409 & REFERENCE INDEX 1409
# NO CALCULATION RESULTS, SKIP FEDS INDEX 70 & REFERENCE INDEX 70
# NO CALCULATION RESULTS, SKIP FEDS INDEX 375 & REFERENCE INDEX 375
# NO CALCULATION RESULTS, SKIP FEDS INDEX 3225 & REFERENCE INDEX 3225
#
#
# PLOTTING ON: BEGIN PLOT OUTPUT
# PLOTTING COMPLETE
#
#
# CSV output complete! Check file /projects/my-public-bucket/VEDA-PEC/results/kincade_fire_demo.csv for results. NOTE: None result rows were excluded.

# %% [markdown]
# ### Tif Analysis on Symmetric Difference Matches (Exceeding Areas of FEDS over Reference)
#
# This function built into the Output Class demonstrates research application uses of FEDS-PEC
#
# Given the output matches, give a tif path, calculations of interest, and optional time (in days) limit. This will return associated TIF values for the symmetric difference of FEDS over the reference (FEDS - reference)

# %%
# tif_path - replace with your own path
tif_path = "/projects/my-public-bucket/tif_files/slopeLF/LC20_SlpD_220.tif"
# array of values returned as get_res
get_res = my_output.tif_analysis(tif_path, "MEDIAN", 100)

# %% [markdown]
# ### Export Polygons
#
# Provide a path along with polygons, and then call on the `export_polygons` method for your OutputCalculation object

# %%
# name your file
shp_file_name = "feds_used"
# resuses the same dir as the csv export 
output_shp_path = f"{user_path}/{shp_file_name}.shp"

my_output.export_polygons(feds_firenrt.polygons, output_shp_path)
