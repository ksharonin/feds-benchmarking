# %% [markdown]
# # Demo: United States 2018-2020 Archive Analysis Run

# %% [markdown]
# ### Summary
#
# This notebook demonstrates an Object Oriented Programming (OOP) implementation of a benchmarking system to compare a FEDS fire perimeter against other fire perimeter data sources, and then store in an output object.
#
# *This particularly demonstrates ability to iterate over all available FEDS and create mass analysis results*
#
# NOTE: This notebook was run in 1-2 month intervals due to the FEDS API item limit. For your range, if you recieve an error on the limit, try to reduce your time window. A year will need to be broken into ~8-10 intervals
#
# Sources for demonstration:
# - FEDS archived perimeters, labeled as `"public.eis_fire_lf_perimeter_archive"`
# - NIFC historic perimeters, labeled as `"nifc_interagency_history_local"`
#
# The FEDS input and reference input can use either a pre-defined setting or can accept (valid) user-written paths to shape files.
# - For Input all settings, please see **section INPUT SETTINGS of README.md**
# - Output settings can also be modified to control if calculations are printed, plotted, and/or stored into a file (with location and file type of choice); for more detail on outputs please see **section OUTPUT SETTINGS of README.md**
#
# #### Motivation
# FEDS-PEC eliminates the need for users to recreate/repeat solutions when conducting geospatial data evaluations. By leveraging this module, researchers and analysts can quickly and efficiently compare the FEDS fireperimeter dataset against a reference data set of their choosing. Users can focus their efforts on dataset selection and analysis, rather than spending time implementing and testing software for comparisons and calculations.

# %% [markdown]
# ### User Inputs for Comparison: time, bbox, FEDS set, reference set
#
# Note for inputs:
#
# FEDS Input: you must specify a valid title (e.g. firenrt) and collection (e.g. public.eis_fire_lf_perimeter_archive) according to documentation. Please see **section INPUT SETTINGS of README.md** for valid titles and corresponding collections
#
# Reference Input: See **section INPUT SETTINGS of README.md** for valid titles and corresponding collections

# %%
import sys
sys.path.append('../') # local path append

import Utilities
import Input_FEDS
import Input_Reference
import Output_Calculation

from Input_FEDS import InputFEDS
from Input_Reference import InputReference
from Output_Calculation import OutputCalculation
from Utilities import *

# %%
# this is the ONLY thing users are intended to modify!
# inputs for searching FEDS and nifc sets

# START TIME
year_start = 2018
month_start = 9 # 6
day_start = 1 # 1
hour_start = 0
minute_start = 0
second_start = 0
tz_offset_hours_start = 0
tz_offset_minutes_start = 0
utc_offset_start = '00:00'

# END TIME
year_stop = 2018
month_stop = 9
day_stop = 30
hour_stop = 0
minute_stop = 0
second_stop = 0
tz_offset_hours_stop = 0
tz_offset_minutes_stop = 0
utc_offset_stop = '00:00'

# CRS - 4326 RECOMMENDED FEDS FIRE PERIM DEFAULT
crs = 3857 # 4326

# BBOX FOR SEARCH - [lon, lat, lon, lat]
search_bbox = ["-125.0", "24.396308", "-66.93457", "49.384358"] 

day_search_range = 7 # acceptable distance to search from feds -> reference (e.g. if refernce polygon is 8 days away, it is not included in calculations)

# FEDS INPUT SETTINGS  # [Change to FEDS Input settings]
feds_title = "firenrt"
feds_collection =  "public.eis_fire_lf_perimeter_archive"
feds_access_type = "api"
feds_limit = 9000 # amount of features to consider for FEDS API access; warning appears if it misses any entries
feds_filter = False
feds_apply_finalfire = True

# REFERENCE INPUT SETTINGS 
ref_title = "InterAgencyFirePerimeterHistory_All_Years_View"# "nifc_interagency_history_local" # this is a predefined set example
ref_control_type = "defined" # or "custom"
ref_custom_url = "none" # not custom for demo
ref_custom_read_type = "none"  # not custom for demo
ref_filter = False # False or a valid query

# OUTPUT SETTINGS - User discretion advised for path functionality
print_on = True
plot_on = True
name_for_output_file = "2018_sept_analysis"
output_format = "csv"
user_path = "/projects/my-public-bucket/VEDA-PEC/results"
output_maap_url = f"{user_path}/{name_for_output_file}.{output_format}"

# %% [markdown]
# ### Argument Processing: format and check to report any issues
# - Note: upon instance instantiation we can also get reports back of invalidity -> any warnings/errors should be addressed

# %%
# start date formatting
search_start = Utilities.format_datetime(year_start, 
                                         month_start, 
                                         day_start, 
                                         hour_start, 
                                         minute_start, 
                                         second_start, 
                                         tz_offset_hours_start, 
                                         tz_offset_minutes_start,
                                         utc_offset_start)
# stop date formatting
search_stop = Utilities.format_datetime(year_stop, 
                                        month_stop, 
                                        day_stop, 
                                        hour_stop, 
                                        minute_stop, 
                                        second_stop, 
                                        tz_offset_hours_stop, 
                                        tz_offset_minutes_stop,
                                        utc_offset_stop)

# bound check the bbox
assert Utilities.check_bbox(search_bbox), f"ERR: passed bbox {search_bbox} is not valid; check bounds"
assert  Utilities.check_crs(crs), f"ERR: invalid crs provided {crs}; please enter valid ESPG CRS number"

# %% [markdown]
# ### Using Inputs: Instantiate Inputs + Calculation Output
#
# With our inputs, we are ready to start; run this to get the program to fetch the FEDS candidates in the provided time/location window, along with an intersecting NIFC in the specific day range
#
# In this case, we get the latest object of FEDS in the kincade zone + its NIFC closest match, which is about 6 days away and heavily intersecting

# %%
# create instances to track properties
print('You may see an ERROR 1 occur; ignore this unless block throws actual exception...')

feds_firenrt = InputFEDS(
                 feds_title, 
                 feds_collection, 
                 search_start,
                 search_stop,
                 search_bbox,
                 crs,
                 feds_access_type,
                 feds_limit,
                 feds_filter,
                 feds_apply_finalfire
                )

nifc_search = InputReference( 
                 search_start,
                 search_stop,
                 search_bbox,
                 crs,
                 ref_title,
                 ref_control_type,
                 ref_custom_url,
                 ref_custom_read_type,
                 ref_filter,
                )

my_output = OutputCalculation(
                feds_firenrt,
                nifc_search,
                output_format, 
                output_maap_url,
                day_search_range,
                print_on,
                plot_on
                )
# Out:
# You may see an ERROR 1 occur; ignore this unless block throws actual exception...
# Running FEDS-Reference Match Algorithm:  26%|██▌       | 48/185 [00:38<01:49,  1.25polygon/s]
# FAILED TIME WINDOW: No matching dates found even with provided day search range window: 7, critical benchmarking failure.
# Due to failing window, use first intersection as value
# Running FEDS-Reference Match Algorithm:  29%|██▉       | 54/185 [00:43<01:45,  1.24polygon/s]
# FAILED TIME WINDOW: No matching dates found even with provided day search range window: 7, critical benchmarking failure.
# Due to failing window, use first intersection as value
# Running FEDS-Reference Match Algorithm:  47%|████▋     | 87/185 [01:10<01:19,  1.23polygon/s]
# FAILED TIME WINDOW: No matching dates found even with provided day search range window: 7, critical benchmarking failure.
# Due to failing window, use first intersection as value
# Running FEDS-Reference Match Algorithm:  62%|██████▏   | 114/185 [01:32<00:57,  1.24polygon/s]
# FAILED TIME WINDOW: No matching dates found even with provided day search range window: 7, critical benchmarking failure.
# Due to failing window, use first intersection as value
# Running FEDS-Reference Match Algorithm:  91%|█████████ | 168/185 [02:16<00:14,  1.19polygon/s]
# FAILED TIME WINDOW: No matching dates found even with provided day search range window: 7, critical benchmarking failure.
# All measurements in units metre
# CALCULATED A RESULT: POLYGON FEDS AT INDEX 817 AGAINST REFERENCE POLYGON AT INDEX 19859:
# Ratio: 1.2110083217165817, Accuracy: 0.957133823715821, Precision: 0.8146889892853035, Recall: 0.9865951456353736, IOU: 0.6719575725903049, F1 0.8924391065786684, Symmetric Ratio: 0.23781803044583652
# All measurements in units metre
# NO CALCULATION RESULTS, SKIP FEDS INDEX 2531 & REFERENCE INDEX 2531
# NO CALCULATION RESULTS, SKIP FEDS INDEX 802 & REFERENCE INDEX 802
# NO CALCULATION RESULTS, SKIP FEDS INDEX 5896 & REFERENCE INDEX 5896
# NO CALCULATION RESULTS, SKIP FEDS INDEX 5929 & REFERENCE INDEX 5929
# NO CALCULATION RESULTS, SKIP FEDS INDEX 2672 & REFERENCE INDEX 2672
# NO CALCULATION RESULTS, SKIP FEDS INDEX 840 & REFERENCE INDEX 840
# CALCULATED A RESULT: POLYGON FEDS AT INDEX 5393 AGAINST REFERENCE POLYGON AT INDEX 11216:
# Ratio: 85534.5020451255, Accuracy: 0.5027599953619506, Precision: 1.1691188655923068e-05, Recall: 0.9999999999999997, IOU: 1.1691086567390089e-05, F1 2.3382103947257717e-05, Symmetric Ratio: 85533.50204512557
# All measurements in units metre
# CALCULATED A RESULT: POLYGON FEDS AT INDEX 5393 AGAINST REFERENCE POLYGON AT INDEX 11233:
# Ratio: 9.503290667736259, Accuracy: 0.7923387200178394, Precision: 0.09876163306215267, Recall: 0.9385605058099483, IOU: 0.09532365576929451, F1 0.17871742018775022, Symmetric Ratio: 8.626169656116373
# All measurements in units metre
# CALCULATED A RESULT: POLYGON FEDS AT INDEX 5393 AGAINST REFERENCE POLYGON AT INDEX 11234:
# Ratio: 1.1296973045686296, Accuracy: 1.3261857120270453, Precision: 0.8574727283405232, Recall: 0.9686846299473979, IOU: 0.6776419633135818, F1 0.9096923096717775, Symmetric Ratio: 0.1923280446738309
# All measurements in units metre
# CALCULATED A RESULT: POLYGON FEDS AT INDEX 5393 AGAINST REFERENCE POLYGON AT INDEX 11263:
# Ratio: 3812.5381061456233, Accuracy: 0.5027351991182105, Precision: 0.00026229246033975353, Recall: 0.9999999999999999, IOU: 0.00026219916978733145, F1 0.0005244473620905855, Symmetric Ratio: 3811.538106145627
# All measurements in units metre
# CALCULATED A RESULT: POLYGON FEDS AT INDEX 5393 AGAINST REFERENCE POLYGON AT INDEX 11265:
# Ratio: 30.58337474601822, Accuracy: 0.5419057056959928, Precision: 0.0035104361088312253, Recall: 0.10736098303833937, IOU: 0.0032454278985690663, F1 0.006798575763463946, Symmetric Ratio: 31.368652779941513
# All measurements in units metre
# CALCULATED A RESULT: POLYGON FEDS AT INDEX 5393 AGAINST REFERENCE POLYGON AT INDEX 16826:
# Ratio: 2134.724272626714, Accuracy: 0.5025533317579995, Precision: 1.1412053478753728e-05, Recall: 0.024361587561609714, IOU: 1.1395889343152942e-05, F1 2.2813420134657692e-05, Symmetric Ratio: 2135.6755494515933
# All measurements in units metre
# CALCULATED A RESULT: POLYGON FEDS AT INDEX 5393 AGAINST REFERENCE POLYGON AT INDEX 16827:
# Ratio: 3167.5544327516213, Accuracy: 0.5027403021815221, Precision: 0.0003157009678066718, Recall: 1.0000000000000002, IOU: 0.0003155784581374305, F1 0.0006312026643213351, Symmetric Ratio: 3166.554432751624
# All measurements in units metre
# NO CALCULATION RESULTS, SKIP FEDS INDEX 3462 & REFERENCE INDEX 3462
# NO CALCULATION RESULTS, SKIP FEDS INDEX 1053 & REFERENCE INDEX 1053
# NO CALCULATION RESULTS, SKIP FEDS INDEX 1040 & REFERENCE INDEX 1040
# NO CALCULATION RESULTS, SKIP FEDS INDEX 5451 & REFERENCE INDEX 5451
# NO CALCULATION RESULTS, SKIP FEDS INDEX 752 & REFERENCE INDEX 752
# NO CALCULATION RESULTS, SKIP FEDS INDEX 4103 & REFERENCE INDEX 4103
# NO CALCULATION RESULTS, SKIP FEDS INDEX 647 & REFERENCE INDEX 647
# NO CALCULATION RESULTS, SKIP FEDS INDEX 4608 & REFERENCE INDEX 4608
# NO CALCULATION RESULTS, SKIP FEDS INDEX 4218 & REFERENCE INDEX 4218
#
#
# PLOTTING ON: BEGIN PLOT OUTPUT
# PLOTTING COMPLETE
#
#
# CSV output complete! Check file /projects/my-public-bucket/VEDA-PEC/results/2018_sept_analysis.csv for results. NOTE: None result rows were excluded.

# %% [markdown]
# ### Tif Analysis on Symmetric Difference Matches (Exceeding Areas of FEDS over Reference)
#
# This function built into the Output Class demonstrates research application uses of FEDS-PEC
#
# Given the output matches, give a tif path, calculations of interest, and optional time (in days) limit. This will return associated TIF values for the symmetric difference of FEDS over the reference (FEDS - reference)

# %%
tif_path = "/projects/shared-buckets/ksharonin/tif_files/slopeLF/LC20_SlpD_220.tif"

get_res = my_output.tif_analysis(tif_path, "MEDIAN", 100)
# Out:
# debug ref_inst issue
#        OBJECTID MAP_METHOD  DATE_CUR COMMENTS   GEO_ID IRWINID  \
# 19854     19855   Infrared  20180826     None  3704296    None
#
#               UNQE_FIRE_ FIRE_YEAR LOCAL_NUM      INCIDENT UNIT_ID POO_RESP_I  \
# 19854  2018-CAHIA-000115      2018    000115  MILL CREEK 1   CAHIA       None
#
#       FEATURE_CA  GIS_ACRES        USER_NAME SOURCE AGENCY  FIRE_YEAR_  \
# 19854   Wildfire     3636.8  Diane Abendroth  WFDSS    BIA      2018.0
#
#          Shape__Are    Shape__Len  \
# 19854  2.597311e+07  40332.568686
#
#                                                 geometry  DATE_NOT_NONE  \
# 19854  POLYGON ((-123.632 41.163, -123.631 41.163, -1...           True
#
#        DATE_LEN_VALID DATE_CUR_STAMP  index
# 19854            True     2018-08-26  19854
# 19854   2018-08-26
# Name: DATE_CUR_STAMP, dtype: datetime64[ns]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [6], in <cell line: 3>()
#       1 tif_path = "/projects/shared-buckets/ksharonin/tif_files/slopeLF/LC20_SlpD_220.tif"
# ----> 3 get_res = my_output.tif_analysis(tif_path, "MEDIAN", 20)
#
# File ~/my-public-bucket/VEDA-PEC/demos/../Output_Calculation.py:592, in OutputCalculation.tif_analysis(self, tif_path, req_calc, date_restrict)
#     590 # assert of datetime type
#     591 feds_time = datetime.strptime(feds_inst.t.values[0], "%Y-%m-%dT%H:%M:%S")
# --> 592 is_within_time_given = OutputCalculation.get_nearest_by_date(ref_inst, feds_time, date_restrict)
#     593 if not is_within_time_given:
#     594     continue
#
# File ~/my-public-bucket/VEDA-PEC/demos/../Output_Calculation.py:344, in OutputCalculation.get_nearest_by_date(dataset, timestamp, dayrange)
#     341 if abs(timestamp.day - res.day) > dayrange and dayrange == 7:
#     342     return None
# --> 344 assert abs(timestamp.day - res.day) <= dayrange, "FATAL: No dates found in specified range; try a more flexible range by adjusting `dayrange` var"
#     345 # fetch rows with res timestamp
#     346 finalized = dataset[dataset['DATE_CUR_STAMP'] == res]
#
# AssertionError: FATAL: No dates found in specified range; try a more flexible range by adjusting `dayrange` var

# %% [markdown]
# ### Export Polygons
#
# Provide a path along with polygons, and then call on the `export_polygons` method for your OutputCalculation object

# %%
# name your file
shp_file_name = "feds_used"
# resuses the same dir as the csv export 
output_shp_path = f"{user_path}/{shp_file_name}.shp"

my_output.export_polygons(feds_firenrt.polygons, output_shp_path)
